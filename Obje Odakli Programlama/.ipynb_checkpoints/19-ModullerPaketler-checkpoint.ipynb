# %%
import numpy as np
import matplotlib.pyplot as matplot

# %%
maasListesi = np.random.normal(4000,500,1000)
np.mean(maasListesi)
# Out:
# np.float64(3971.7178539135766)

# %%
matplot.hist(maasListesi, 50)
matplot.show()
